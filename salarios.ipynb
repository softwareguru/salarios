# %%
import pandas as pd
import numpy as np
df = pd.read_csv("answers.csv", index_col=0)
df.head()
# Out:
#                        created  salarymx  salaryusd  extramx  extrausd  \
# id
# 1   2019-12-23 22:14:57.072546     80000          0    60000         0
# 2   2019-12-23 22:19:42.131242     28000          0       28         0
# 3   2019-12-23 22:19:53.567686     26000          0    40000         0
# 4   2019-12-23 22:24:04.580942     35000          0    18000         0
# 5   2019-12-23 22:24:22.759488     17000          0   219000         0
#
#     variation  english_num                                      english_label  \
# id
# 1          20            4  Avanzado: Puedo conversar y escribir sin probl...
# 2           5            1    Elemental: Sé lo básico para sobrevivir (ILR 1)
# 3           4            2  Limitado: Me doy a entender pero con errores d...
# 4          30            3  Profesional: Puedo interactuar profesionalment...
# 5           0            1    Elemental: Sé lo básico para sobrevivir (ILR 1)
#
# ...
